# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Helper_Functions import *
from FT_class import *
import logging
logging.getLogger().setLevel(logging.INFO)
from Visual import *
# from dna_painter import *
from DNAMask import *
from Backend import *

# %%
b = Backend()
b.change_file_name('in/lena.jpg')
b.change_config({'encoding method':'DNA Mask'})
# Out:
# {'gc_out_of_range': 372,
#  'chunks_with_long_homo': 969,
#  'chunk_num': 1156,
#  'file_size': 36976}

# %%
dic = b.start_encoding()
b.save_encoding_result()
# Out:
# 0
# 1
# 3
# 5
# 6
# 8
# 10
# 12
# 13
# 15
# 17
# 19
# 20
# 22
# 24
# 25
# 27
# 29
# 31
# 32
# 34
# 36
# 38
# 39
# 41
# 43
# 44
# 46
# 48
# 50
# 51
# 53
# 55
# 57
# 58
# 60
# 62
# 64
# 65
# 67
# 69
# 70
# 72
# 74
# 76
# 77
# 79
# 81
# 83
# 84
# 86
# 88
# 89
# 91
# 93
# 95
# 96
# 98

# %%
b.decode('pool/lena.dna')
# Out:
# 1
# 3
# 5
# 6
# 8
# 10
# 12
# 13
# 15
# 17
# 19
# 20
# 22
# 24
# 25
# 27
# 29
# 31
# 32
# 34
# 36
# 38
# 39
# 41
# 43
# 44
# 46
# 48
# 50
# 51
# 53
# 55
# 57
# 58
# 60
# 62
# 64
# 65
# 67
# 69
# 70
# 72
# 74
# 76
# 77
# 79
# 81
# 83
# 84
# 86
# 88
# 89
# 91
# 93
# 95
# 96
# 98
